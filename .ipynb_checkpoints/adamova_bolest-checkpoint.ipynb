# %% [markdown]
# # Vyhodnocení dat pro Adama

# %%
# Install and load necessary packages
if(!require(ggplot2)) install.packages("ggplot2")
require(dplyr)
require(ggplot2)
library(dplyr)
library(ggplot2)

# %%
data_1 <- read.csv("C:/Users/jsuch/Desktop/scholz/data - Skupina 1.csv") #nactu data
data_3 <- read.csv("C:/Users/jsuch/Desktop/scholz/data - Skupina 3.csv") #nactu data

# Function to convert columns from factor to numeric
convert_factor_to_numeric <- function(data) {
  data[, 6:ncol(data)] <- lapply(data[, 6:ncol(data)], function(column) {
    if (is.factor(column)) {
      as.numeric(as.character(column))
    } else {
      column
    }
  })
  return(data)
}

# Apply the function to data_1 and data_3
data_1 <- convert_factor_to_numeric(data_1)
data_3 <- convert_factor_to_numeric(data_3)

# %% [markdown]
# Adame, kód níže vezme pro skupiny 1 a 3 každý sloupec a použije Wilcoxonův test k otestování, jestli můžeme tvrdit, že jedna skupina má nižší nebo vyšší hodnotu pro daný sloupec než druhá. Kdyžtak zkonzultuj umělou inteligenci nebo někoho ze semináře nebo mě. Ale v první řadě zkus googlit a použít AI.

# %%
for(i in 6:ncol(data_1)){
    mean_1 <- mean(data_1[,i])
    mean_3 <- mean(data_3[,i])
    print(colnames(data_1)[i])
    if(mean_1 < mean_3){
        test_result <- wilcox.test(data_1[,i], data_3[,i], alternative = "less")
        print("Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3")
    } else {
        test_result <- wilcox.test(data_1[,i], data_3[,i], alternative = "greater")
        print("Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3")
    }
    
    print(test_result)
}
# Out:
# [1] "B.cells..Freq.of.lymph.."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "less"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 29, p-value = 0.2712
# alternative hypothesis: true location shift is less than 0
#
# [1] "Memory.B.cells..Freq.of.B.cells.."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 43, p-value = 0.2766
# alternative hypothesis: true location shift is greater than 0
#
# [1] "CD21low..Freq.of.B.cells.."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 47, p-value = 0.1677
# alternative hypothesis: true location shift is greater than 0
#
# [1] "Naive.like.CD21low..IgD.CD27..Freq.of.B.cells.."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 50, p-value = 0.1064
# alternative hypothesis: true location shift is greater than 0
#
# [1] "Class.switched.like.CD21low..IgD.CD27..Freq.of.B.cells.."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "greater"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 42, p-value = 0.303
# alternative hypothesis: true location shift is greater than 0
#
# [1] "DN.CD21low..IgD.CD27..Freq.of.B.cells.."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 31, p-value = 0.341
# alternative hypothesis: true location shift is less than 0
#
# [1] "Naive.B.cells..Freq.of.B.cells.."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 35, p-value = 0.4818
# alternative hypothesis: true location shift is less than 0
#
# [1] "Marginal.zone.like.B.cells..Freq.of.B.cells.."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 41, p-value = 0.341
# alternative hypothesis: true location shift is greater than 0
#
# [1] "Class.switched..Freq.of.B.cells.."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 47, p-value = 0.1677
# alternative hypothesis: true location shift is greater than 0
#
# [1] "Plazmablasty..Freq.of.B.cells.."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 33, p-value = 0.41
# alternative hypothesis: true location shift is less than 0
#
# [1] "TransientnÃ..B.cells..Freq.of.B.cells.."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 31, p-value = 0.6918
# alternative hypothesis: true location shift is greater than 0
#
# [1] "CCR7..MFI.of.B.cells."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 32, p-value = 0.3751
# alternative hypothesis: true location shift is less than 0
#
# [1] "CXCR3..MFI.of.B.cells."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "greater"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 44.5, p-value = 0.2266
# alternative hypothesis: true location shift is greater than 0
#
# [1] "CCR7..MFI.of.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 31, p-value = 0.341
# alternative hypothesis: true location shift is less than 0
#
# [1] "CXCR3..MFI.of.CD21low."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "greater"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 49, p-value = 0.1207
# alternative hypothesis: true location shift is greater than 0
#
# [1] "CCR7..MFI.of.Naive.like.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 32, p-value = 0.3751
# alternative hypothesis: true location shift is less than 0
#
# [1] "CXCR3..MFI.of.Naive.like.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 34, p-value = 0.4458
# alternative hypothesis: true location shift is less than 0
#
# [1] "CCR7..MFI.of.Class.switched.like.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 29, p-value = 0.2766
# alternative hypothesis: true location shift is less than 0
#
# [1] "CXCR3..MFI.of.Class.switched.like.CD21low."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 35, p-value = 0.5542
# alternative hypothesis: true location shift is greater than 0
#
# [1] "CCR7..MFI.of.DN.CD21low."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "less"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 25, p-value = 0.1626
# alternative hypothesis: true location shift is less than 0
#
# [1] "CXCR3..MFI.of.DN.CD21low."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 60, p-value = 0.01223
# alternative hypothesis: true location shift is greater than 0
#
# [1] "CCR7..MFI.of.Naive.B.cells."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 26, p-value = 0.1923
# alternative hypothesis: true location shift is less than 0
#
# [1] "CXCR3..MFI.of.Naive.B.cells."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 35, p-value = 0.5542
# alternative hypothesis: true location shift is greater than 0
#
# [1] "CCR7..MFI.of.Memory.B.cells."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 30, p-value = 0.3082
# alternative hypothesis: true location shift is less than 0
#
# [1] "CXCR3..MFI.of.Memory.B.cells."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "less"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 33.5, p-value = 0.4256
# alternative hypothesis: true location shift is less than 0
#
# [1] "CCR7..MFI.of.Class.switched.B.cells."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 30, p-value = 0.3082
# alternative hypothesis: true location shift is less than 0
#
# [1] "CXCR3..MFI.of.Class.switched.B.cells."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "less"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 36, p-value = 0.5187
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD40..MFI.of..B.cells."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 22, p-value = 0.1064
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD80.86..MFI..of..B.cells."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 25, p-value = 0.1677
# alternative hypothesis: true location shift is less than 0
#
# [1] "HLA.DR..MFI..of..B.cells."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "less"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 28, p-value = 0.2411
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD40..MFI..of..CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 21, p-value = 0.08985
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD80.86..MFI..of.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 32, p-value = 0.3751
# alternative hypothesis: true location shift is less than 0
#
# [1] "HLA.DR..MFI.of.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 30, p-value = 0.3082
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD40..MFI..of..Naive.like.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 24, p-value = 0.1454
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD80.86..MFI..of.Naive.like.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 22, p-value = 0.1064
# alternative hypothesis: true location shift is less than 0
#
# [1] "HLA.DR..MFI.of.Naive.like.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 22, p-value = 0.1064
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD40..MFI..of..Class.switched.CD21low."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 36, p-value = 0.5182
# alternative hypothesis: true location shift is greater than 0
#
# [1] "CD80.86..MFI..of.Class.switched.CD21low."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "greater"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 42, p-value = 0.3031
# alternative hypothesis: true location shift is greater than 0
#
# [1] "HLA.DR..MFI.of.Class.switched.CD21low."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 37, p-value = 0.4818
# alternative hypothesis: true location shift is greater than 0
#
# [1] "CD40..MFI..of..DN.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 22, p-value = 0.1064
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD80.86..MFI..of.DN.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 32, p-value = 0.3751
# alternative hypothesis: true location shift is less than 0
#
# [1] "HLA.DR..MFI.of.DN.CD21low."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 31, p-value = 0.341
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD40..MFI.of..Naive.B."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 24, p-value = 0.1454
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD80.86..MFI.of.Naive.B."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 16, p-value = 0.0334
# alternative hypothesis: true location shift is less than 0
#
# [1] "HLA.DR..MFI.of.Naive.B."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 25, p-value = 0.1677
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD40..MFI.of..Memory.B."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 27, p-value = 0.2185
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD80.86..MFI.of.Memory.B."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 26, p-value = 0.1923
# alternative hypothesis: true location shift is less than 0
#
# [1] "HLA.DR..MFI.of.Memory.B."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 23, p-value = 0.1248
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD40..MFI.of..Class.switched.B."
# [1] "Prumer pro skupinu 1  je mensi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 36, p-value = 0.5182
# alternative hypothesis: true location shift is less than 0
#
# [1] "CD80.86..MFI.of.Class.switched..B."
# Warning message in wilcox.test.default(data_1[, i], data_3[, i], alternative = "greater"):
# "cannot compute exact p-value with ties"
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data_1[, i] and data_3[, i]
# W = 44, p-value = 0.2411
# alternative hypothesis: true location shift is greater than 0
#
# [1] "HLA.DR..MFI.of.Class.switched..B."
# [1] "Prumer pro skupinu 1  je vetsi nez prumer pro skupinu 3"
#
# 	Wilcoxon rank sum test
#
# data:  data_1[, i] and data_3[, i]
# W = 39, p-value = 0.41
# alternative hypothesis: true location shift is greater than 0

# %% [markdown]
# Dále udělám korelace, dělám je pro každou ze skupin zvlášť.

# %%
data_1[,3] <- as.numeric(data_1[,3])
data_3[,3] <- as.numeric(data_3[,3])


head(data_1)
# Out:
#   Pacient PohlavÃ. VÄ.k Myasthenia.Gravis.ANO.NE
# 1 P1      Å½       NA   ANO
# 2 P2      Å½       27   ANO
# 3 P3      Å½       NA   ANO
# 4 P4      M        23   ANO
# 5 P5      M        30   ANO
# 6 P6      Å½       53   ANO
#   Histologie                       B.cells..Freq.of.lymph..
# 1 hyperplÃ¡zie. MG                  2.28
# 2 folikulÃ¡rnÃ­ hyperplÃ¡zie thymu  4.01
# 3 bez patologickÃ©ho nÃ¡lezu        1.52
# 4                                  14.60
# 5 folikulÃ¡rnÃ­ hyperplÃ¡zie thymu  9.07
# 6 bez patologickÃ©ho nÃ¡lezu       14.70
#   Memory.B.cells..Freq.of.B.cells.. CD21low..Freq.of.B.cells..
# 1 26.2                              75.0
# 2 50.3                              50.7
# 3 64.1                              66.2
# 4 41.6                              87.6
# 5 43.4                              65.8
# 6 57.4                              84.5
#   Naive.like.CD21low..IgD.CD27..Freq.of.B.cells..
# 1 11.30
# 2  7.34
# 3  1.94
# 4 15.70
# 5 12.50
# 6  2.07
#   Class.switched.like.CD21low..IgD.CD27..Freq.of.B.cells.. ...
# 1  8.7                                                     ...
# 2 26.4                                                     ...
# 3 46.1                                                     ...
# 4 36.2                                                     ...
# 5 28.0                                                     ...
# 6 51.5                                                     ...
#   HLA.DR..MFI.of.DN.CD21low. CD40..MFI.of..Naive.B. CD80.86..MFI.of.Naive.B.
# 1  9583                      4392                    743
# 2  8271                      5307                   1067
# 3  9595                      5761                   1703
# 4  7884                      4146                   1957
# 5 10268                      6500                   1345
# 6  8506                      3281                   3387
#   HLA.DR..MFI.of.Naive.B. CD40..MFI.of..Memory.B. CD80.86..MFI.of.Memory.B.
# 1 18785                   5510                    2346
# 2 15184                   6074                    1722
# 3 15152                   7311                    3058
# 4 14210                   4019                    4020
# 5 18556                   6826                    2602
# 6  9390                   5940                    4576
#   HLA.DR..MFI.of.Memory.B. CD40..MFI.of..Class.switched.B.
# 1 16762                    5549
# 2 11397                    6075
# 3 12557                    7322
# 4 11115                    4000
# 5 14378                    6883
# 6 15750                    6050
#   CD80.86..MFI.of.Class.switched..B. HLA.DR..MFI.of.Class.switched..B.
# 1 2638                               16776
# 2 1689                               10945
# 3 3052                               12512
# 4 4198                               10960
# 5 2813                               13996
# 6 4361                               15824

# %%
# Function to calculate Pearson correlation for specific columns
calculate_pearson_correlations <- function(data, target_column, pattern) {
  # Ensure the target column exists
  if (ncol(data) < target_column) {
    stop("The target column index exceeds the number of columns in the dataframe.")
  }
  
  # Get column names matching the pattern
  matching_columns <- grep(pattern, colnames(data), value = TRUE)
  
  print(matching_columns)
  # Initialize a result list
  results <- list()
  
  # Iterate over matching columns
  for (col_name in matching_columns) {
    # Get column names for axis labels
    target_column_name <- colnames(data)[target_column]
    current_column_name <- str(col_name)
    
    # Calculate Pearson correlation
    correlation <- cor(data[[target_column]], data[[col_name]], use = "complete.obs", method = "pearson")
    
    # Linear regression
    model <- lm(data[[target_column]] ~ data[[col_name]], data = data)  
    model_summary <- summary(model)
    regression_coeff <- model_summary$coefficients[2, 1]  # Coefficient for independent variable
    p_value <- model_summary$coefficients[2, 4]    
    
    # Create the plot
    plot <- ggplot(data, aes(x = data[[col_name]], y = data[[target_column]])) +
      geom_point(color = "blue", alpha = 0.6) +
      geom_smooth(method = "lm", color = "red", se = FALSE) +
      labs(
        title = "",
        x = current_column_name,  # Adjusted: Use current column name for x-axis
        y = target_column_name    # Adjusted: Use target column name for y-axis
      ) +
      theme_minimal() +
      annotate(
        "text",
        x = Inf, y = -Inf, hjust = 1.1, vjust = -0.5,
        label = paste0(
          "Pearsonova korelace: ", round(correlation, 2), "\n",
          "Regresní koeficient pro nezávislou proměnnou: ", round(regression_coeff, 2), "\n",
          "p-hodnota: ", format.pval(p_value, digits = 3)
        ),
        size = 4, color = "black"
      )
    
    # Print the plot
    print(plot)
    
    # Store the result
    results[[col_name]] <- correlation
  }
  
}

# Calculate Pearson correlations for the third column against columns with "CD21low" in their names
pearson_results_1 <- calculate_pearson_correlations(data_1, target_column = 3, pattern = "CD21low")
# Out:
#  [1] "CD21low..Freq.of.B.cells.."
#  [2] "Naive.like.CD21low..IgD.CD27..Freq.of.B.cells.."
#  [3] "Class.switched.like.CD21low..IgD.CD27..Freq.of.B.cells.."
#  [4] "DN.CD21low..IgD.CD27..Freq.of.B.cells.."
#  [5] "CCR7..MFI.of.CD21low."
#  [6] "CXCR3..MFI.of.CD21low."
#  [7] "CCR7..MFI.of.Naive.like.CD21low."
#  [8] "CXCR3..MFI.of.Naive.like.CD21low."
#  [9] "CCR7..MFI.of.Class.switched.like.CD21low."
# [10] "CXCR3..MFI.of.Class.switched.like.CD21low."
# [11] "CCR7..MFI.of.DN.CD21low."
# [12] "CXCR3..MFI.of.DN.CD21low."
# [13] "CD40..MFI..of..CD21low."
# [14] "CD80.86..MFI..of.CD21low."
# [15] "HLA.DR..MFI.of.CD21low."
# [16] "CD40..MFI..of..Naive.like.CD21low."
# [17] "CD80.86..MFI..of.Naive.like.CD21low."
# [18] "HLA.DR..MFI.of.Naive.like.CD21low."
# [19] "CD40..MFI..of..Class.switched.CD21low."
# [20] "CD80.86..MFI..of.Class.switched.CD21low."
# [21] "HLA.DR..MFI.of.Class.switched.CD21low."
# [22] "CD40..MFI..of..DN.CD21low."
# [23] "CD80.86..MFI..of.DN.CD21low."
# [24] "HLA.DR..MFI.of.DN.CD21low."
#  chr "CD21low..Freq.of.B.cells.."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
#  chr "Naive.like.CD21low..IgD.CD27..Freq.of.B.cells.."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "Class.switched.like.CD21low..IgD.CD27..Freq.of.B.cells.."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "DN.CD21low..IgD.CD27..Freq.of.B.cells.."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CCR7..MFI.of.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CXCR3..MFI.of.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CCR7..MFI.of.Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CXCR3..MFI.of.Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CCR7..MFI.of.Class.switched.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CXCR3..MFI.of.Class.switched.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CCR7..MFI.of.DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CXCR3..MFI.of.DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CD40..MFI..of..CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CD80.86..MFI..of.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "HLA.DR..MFI.of.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CD40..MFI..of..Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CD80.86..MFI..of.Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "HLA.DR..MFI.of.Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CD40..MFI..of..Class.switched.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CD80.86..MFI..of.Class.switched.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "HLA.DR..MFI.of.Class.switched.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CD40..MFI..of..DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "CD80.86..MFI..of.DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
#  chr "HLA.DR..MFI.of.DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# plot without title

# %%
# Function to calculate Pearson correlation for specific columns
calculate_pearson_correlations <- function(data, target_column, pattern) {
  # Ensure the target column exists
  if (ncol(data) < target_column) {
    stop("The target column index exceeds the number of columns in the dataframe.")
  }
  
  # Get column names matching the pattern
  matching_columns <- grep(pattern, colnames(data), value = TRUE)
  
  # Print matching columns for debugging
  print(matching_columns)
  
  # Initialize a result list
  results <- list()
  
  # Iterate over matching columns
  for (col_name in matching_columns) {
    # Retrieve column names for axis labels
    target_column_name <- colnames(data)[target_column]
    current_column_name <- col_name
    
    # Print for debugging purposes
    print(paste("Target column (Y):", target_column_name))
    print(paste("Current column (X):", current_column_name))
    
    # Calculate Pearson correlation
    correlation <- cor(data[[target_column]], data[[col_name]], use = "complete.obs", method = "pearson")
    
    # Linear regression
    model <- lm(data[[target_column]] ~ data[[col_name]], data = data)  
    model_summary <- summary(model)
    regression_coeff <- model_summary$coefficients[2, 1]  # Coefficient for independent variable
    p_value <- model_summary$coefficients[2, 4]    
    
    # Create the plot
    plot <- ggplot(data, aes(x = data[[col_name]], y = data[[target_column]])) +
      geom_point(color = "blue", alpha = 0.6) +
      geom_smooth(method = "lm", color = "red", se = FALSE) +
      labs(
        title = "",
        x = current_column_name,  # Correctly assign current column name for x-axis
        y = target_column_name    # Correctly assign target column name for y-axis
      ) +
      theme_minimal() +
      annotate(
        "text",
        x = Inf, y = -Inf, hjust = 1.1, vjust = -0.5,
        label = paste0(
          "Pearsonova korelace: ", round(correlation, 2), "\n",
          "Regresní koeficient pro nezávislou proměnnou: ", round(regression_coeff, 2), "\n",
          "p-hodnota: ", format.pval(p_value, digits = 3)
        ),
        size = 4, color = "black"
      )
    
    # Print the plot
    print(plot)
    
    # Store the result
    results[[col_name]] <- correlation
  }
  
  return(results)
}


pearson_results_1 <- calculate_pearson_correlations(data_1, target_column = 3, pattern = "CD21low")
# Out:
#  [1] "CD21low..Freq.of.B.cells.."
#  [2] "Naive.like.CD21low..IgD.CD27..Freq.of.B.cells.."
#  [3] "Class.switched.like.CD21low..IgD.CD27..Freq.of.B.cells.."
#  [4] "DN.CD21low..IgD.CD27..Freq.of.B.cells.."
#  [5] "CCR7..MFI.of.CD21low."
#  [6] "CXCR3..MFI.of.CD21low."
#  [7] "CCR7..MFI.of.Naive.like.CD21low."
#  [8] "CXCR3..MFI.of.Naive.like.CD21low."
#  [9] "CCR7..MFI.of.Class.switched.like.CD21low."
# [10] "CXCR3..MFI.of.Class.switched.like.CD21low."
# [11] "CCR7..MFI.of.DN.CD21low."
# [12] "CXCR3..MFI.of.DN.CD21low."
# [13] "CD40..MFI..of..CD21low."
# [14] "CD80.86..MFI..of.CD21low."
# [15] "HLA.DR..MFI.of.CD21low."
# [16] "CD40..MFI..of..Naive.like.CD21low."
# [17] "CD80.86..MFI..of.Naive.like.CD21low."
# [18] "HLA.DR..MFI.of.Naive.like.CD21low."
# [19] "CD40..MFI..of..Class.switched.CD21low."
# [20] "CD80.86..MFI..of.Class.switched.CD21low."
# [21] "HLA.DR..MFI.of.Class.switched.CD21low."
# [22] "CD40..MFI..of..DN.CD21low."
# [23] "CD80.86..MFI..of.DN.CD21low."
# [24] "HLA.DR..MFI.of.DN.CD21low."
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CD21low..Freq.of.B.cells.."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): Naive.like.CD21low..IgD.CD27..Freq.of.B.cells.."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): Class.switched.like.CD21low..IgD.CD27..Freq.of.B.cells.."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): DN.CD21low..IgD.CD27..Freq.of.B.cells.."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CCR7..MFI.of.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CXCR3..MFI.of.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CCR7..MFI.of.Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CXCR3..MFI.of.Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CCR7..MFI.of.Class.switched.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CXCR3..MFI.of.Class.switched.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CCR7..MFI.of.DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CXCR3..MFI.of.DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CD40..MFI..of..CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CD80.86..MFI..of.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): HLA.DR..MFI.of.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CD40..MFI..of..Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CD80.86..MFI..of.Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): HLA.DR..MFI.of.Naive.like.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CD40..MFI..of..Class.switched.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CD80.86..MFI..of.Class.switched.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): HLA.DR..MFI.of.Class.switched.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CD40..MFI..of..DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): CD80.86..MFI..of.DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# [1] "Target column (Y): VÄ.k"
# [1] "Current column (X): HLA.DR..MFI.of.DN.CD21low."
# Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."Warning message:
# "Use of `data[[col_name]]` is discouraged. Use `.data[[col_name]]` instead."Warning message:
# "Use of `data[[target_column]]` is discouraged. Use `.data[[target_column]]` instead."`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 3 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 3 rows containing missing values (geom_point)."
# plot without title
# plot without title

# %%
print(pearson_results_3)
# Out:
# $CD21low..Freq.of.B.cells..
# [1] -0.458278
#
# $Naive.like.CD21low..IgD.CD27..Freq.of.B.cells..
# [1] -0.2200192
#
# $Class.switched.like.CD21low..IgD.CD27..Freq.of.B.cells..
# [1] 0.003576166
#
# $DN.CD21low..IgD.CD27..Freq.of.B.cells..
# [1] -0.5761972
#
# $CCR7..MFI.of.CD21low.
# [1] 0.03680879
#
# $CXCR3..MFI.of.CD21low.
# [1] 0.2594229
#
# $CCR7..MFI.of.Naive.like.CD21low.
# [1] 0.2474471
#
# $CXCR3..MFI.of.Naive.like.CD21low.
# [1] -0.05595803
#
# $CCR7..MFI.of.Class.switched.like.CD21low.
# [1] -0.2345733
#
# $CXCR3..MFI.of.Class.switched.like.CD21low.
# [1] 0.03987506
#
# $CCR7..MFI.of.DN.CD21low.
# [1] 0.3219682
#
# $CXCR3..MFI.of.DN.CD21low.
# [1] 0.3223678
#
# $CD40..MFI..of..CD21low.
# [1] -0.3107239
#
# $CD80.86..MFI..of.CD21low.
# [1] 0.2558252
#
# $HLA.DR..MFI.of.CD21low.
# [1] -0.3822554
#
# $CD40..MFI..of..Naive.like.CD21low.
# [1] -0.05345695
#
# $CD80.86..MFI..of.Naive.like.CD21low.
# [1] 0.1651943
#
# $HLA.DR..MFI.of.Naive.like.CD21low.
# [1] -0.5321995
#
# $CD40..MFI..of..Class.switched.CD21low.
# [1] -0.5216656
#
# $CD80.86..MFI..of.Class.switched.CD21low.
# [1] -0.3131129
#
# $HLA.DR..MFI.of.Class.switched.CD21low.
# [1] -0.5724485
#
# $CD40..MFI..of..DN.CD21low.
# [1] -0.283245
#
# $CD80.86..MFI..of.DN.CD21low.
# [1] 0.05863767
#
# $HLA.DR..MFI.of.DN.CD21low.
# [1] -0.5855285
